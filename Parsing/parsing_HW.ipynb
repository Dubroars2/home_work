# %%
#Задание 1.
"""
Обязательная часть
Будем парсить страницу со свежеми новостям на habr.com/ru/all/.
Вам необходимо собирать только те статьи, в которых встречается хотя бы одно требуемое ключевое слово. Эти слова определяем в начале кода в переменной, например:
KEYWORDS = ['python', 'парсинг']
Поиск вести по всей доступной preview-информации (это информация, доступная непосредственно с текущей страницы).
В итоге должен формироваться датафрейм вида: <дата> - <заголовок> - <ссылка>
"""

# %%
import requests

# %%
URL = "https://habr.com/en/search/"
KEYWORDS = ['python', 'парсинг']
params = {
    "q": KEYWORDS[0]
}

# %%
#если 200, то все ок
res = requests.get(URL, params)
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" class="no-js">\n  <head>\n    <meta http-equiv="content-type" content="text/html; charset=utf-8" />\n<meta content=\'width=1024\' name=\'viewport\'>\n<title>Search results for «python» / Habr</title>\n\n\n\n\n\n<meta name=\'yandex-verification\' content=\'71593b225aeafc4e\' />\n<meta name=\'referrer\' content=\'unsafe-url\' />\n<meta name="pocket-site-verification" content="ed24b2b9721edf0a282c5b4a3232c4" />\n<meta name="biu" content="https://dr.habracdn.net/habr/oldassets/607ef699/images/">\n\n<style type="text/css">\n  @font-face{font-family:\'Fira Sans\';font-style:normal;font-weight:500;src:url(https://dr.habracdn.net/habr/oldassets/607ef699/fonts/FiraSans/firaSans-medium.eot);src:local("Fira Sans Medium"),local("FiraSans-Medium"),url(https://dr.habracdn.net/habr/oldassets/607ef699/fonts/FiraSans/firaSans-medium.eot?#iefix) format("embedded-opentype"),url(https://dr.habracdn.net/habr/oldassets/607ef699/fonts/FiraSans/firaSans-medium.woff2) format
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(res.text)
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="width=1024" name="viewport"/>
# <title>Search results for «python» / Habr</title>
# <meta content="71593b225aeafc4e" name="yandex-verification"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="ed24b2b9721edf0a282c5b4a3232c4" name="pocket-site-verification"/>
# <meta content="https://dr.habracdn.net/habr/oldassets/607ef699/images/" name="biu"/>
# <style type="text/css">
# ...

# %%
# добираемся до блоков с новостями
news_block = soup.find_all("h2", class_ = "post__title")
news_block
# Out:
# [<h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/en/company/wargaming/blog/436180/">Things you need to know should you want to switch from PHP to <em class="searched-item">Python</em></a>
#  </h2>,
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/en/post/471134/"><em class="searched-item">Python</em> vs JavaScript: Which One Can Benefit You The Most?</a>
#  </h2>,
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/en/post/484634/">Node.js VS <em class="searched-item">Python</em>: Which is Better?</a>
#  </h2>,
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/en/post/477294/"><em class="searched-item">Python</em> for AI: A match made in heaven</a>
#  </h2>,
#  <h2 class="post__title">
#  <a class="post__title_link" href="https://habr.com/en/post/500464/">Is <em class="searched-item">Python</em> The Answer To High-End Mobile Apps?</a>
#  </h2>,
# ...

# %%
# добираемся до ссылок
text_ref = list(map(lambda x: x.find('a').get('href'), news_block))
text_ref
# Out:
# ['https://habr.com/en/company/wargaming/blog/436180/',
#  'https://habr.com/en/post/471134/',
#  'https://habr.com/en/post/484634/',
#  'https://habr.com/en/post/477294/',
#  'https://habr.com/en/post/500464/',
#  'https://habr.com/en/post/445482/',
#  'https://habr.com/en/post/482500/',
#  'https://habr.com/en/post/526002/',
#  'https://habr.com/en/company/microsoft/blog/455333/',
#  'https://habr.com/en/post/462035/',
#  'https://habr.com/en/company/microsoft/blog/469045/',
#  'https://habr.com/en/company/microsoft/blog/471166/',
#  'https://habr.com/en/company/oleg-bunin/blog/491910/',
#  'https://habr.com/en/company/microsoft/blog/483342/',
#  'https://habr.com/en/post/484102/',
#  'https://habr.com/en/company/microsoft/blog/450708/',
#  'https://habr.com/en/company/microsoft/blog/458100/',
#  'https://habr.com/en/company/oleg-bunin/blog/444220/',
#  'https://habr.com/en/company/JetBrains/blog/533366/',
#  'https://habr.com/en/post/539436/']

# %%
# добираемся до блока страницы
page_block = soup.find_all("div", class_ = "page__footer")
page_block
# Out:
# [<div class="page__footer">
#  <ul class="arrows-pagination">
#  <li class="arrows-pagination__item">
#  <span class="arrows-pagination__item-link">← here</span>
#  </li>
#  <li class="arrows-pagination__item">
#  <a class="arrows-pagination__item-link arrows-pagination__item-link_next" href="/en/search/page2/?q=python&amp;target_type=posts&amp;flow=&amp;order_by=relevance" id="next_page" rel=""><span>there</span> →</a>
#  </li>
#  </ul>
#  <ul class="toggle-menu toggle-menu_pagination" id="nav-pagess">
#  <li class="toggle-menu__item toggle-menu__item_pagination">
#  <span class="toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_active">1</span>
#  </li>
#  <li class="toggle-menu__item toggle-menu__item_pagination">
#  <a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/en/search/page2/?q=python&amp;target_type=posts&amp;flow=&amp;order_by=relevance">2</a>
#  </li>
#  <li class="toggle-menu__item toggle-menu__item_pagination">
# ...

# %%
check_2 = list(map(lambda x: x.find('ul', class_='toggle-menu'), page_block))
check_2
# Out:
# [<ul class="toggle-menu toggle-menu_pagination" id="nav-pagess">
#  <li class="toggle-menu__item toggle-menu__item_pagination">
#  <span class="toggle-menu__item-link toggle-menu__item-link_pagination toggle-menu__item-link_active">1</span>
#  </li>
#  <li class="toggle-menu__item toggle-menu__item_pagination">
#  <a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/en/search/page2/?q=python&amp;target_type=posts&amp;flow=&amp;order_by=relevance">2</a>
#  </li>
#  <li class="toggle-menu__item toggle-menu__item_pagination">
#  <a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/en/search/page3/?q=python&amp;target_type=posts&amp;flow=&amp;order_by=relevance">3</a>
#  </li>
#  <li class="toggle-menu__item toggle-menu__item_pagination">
#  <a class="toggle-menu__item-link toggle-menu__item-link_pagination" href="/en/search/page4/?q=python&amp;target_type=posts&amp;flow=&amp;order_by=relevance">4</a>
#  </li>
# ...

# %%
url_2 = "https://habr.com/en/search/"
KEYWORDS_2 = ['python', 'парсинг']
params = {
    "q": 'python'
}

# %%
KEYWORDS = ['python', 'парсинг']
def get_links(url, query):
    ref_ = []
    params = {"q": query,}
    res = requests.get(url, params)
    time.sleep(0.4)
    soup = BeautifulSoup(res.text, 'html.parser')
    news_block = soup.find_all("h2", class_ = "post__title")
    text_ref = list(map(lambda x: x.find('a').get('href'), news_block))
    
    return ref_
ref_ = get_links(url_2, 'python')
ref_
# Out:
# []

# %%
import time
time.sleep(0.2)

# %%
#Задание 2.
"""
Обязательная часть
Написать скрипт, который будет проверять список e-mail адресов на утечку при помощи сервиса Avast Hack Ckeck. 
Список email-ов задаем переменной в начале кода:
EMAIL = [xxx@x.ru, yyy@y.com]
В итоге должен формироваться датафрейм со столбцами: <почта> - <дата утечки> - <источник утечки> - <описание утечки>
Подсказка: сервис работает при помощи "скрытого" API. Внимательно изучите post-запросы.
"""

# %%
EMAIL = ["king@mail.ru"]

URL_2 = "https://identityprotection.avast.com/v1/web/query/site-breaches/unauthorized-data"
params_2 = {
    "emailAddresses": "king@mail.ru"
}

# %%
#если 200, то все ок
res2 = requests.get(URL_2, params_2)
res2
# Out:
# <Response [404]>
