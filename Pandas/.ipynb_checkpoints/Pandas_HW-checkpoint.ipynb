# %%
#Задание 1
"""
Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. 
Определите какому фильму было выставлено больше всего оценок 5.0.
"""

# %%
import pandas as pd

# %%
data = pd.read_csv("ratings.csv")
data[ data.rating == 5.0 ].sort_values(by = "movieId", ascending = False ).head(10)
# Out:
#        userId  movieId  rating   timestamp
# 71996     462   187717     5.0  1529413865
# 90255     586   187595     5.0  1529899556
# 15246      98   187593     5.0  1532457913
# 46620     305   187593     5.0  1532877841
# 4037       25   187593     5.0  1535470534
# 37419     249   187593     5.0  1531611534
# 9154       62   185135     5.0  1525795293
# 49859     318   184245     5.0  1517774414
# 30515     212   183897     5.0  1532361617
# 4035       25   180095     5.0  1535470476

# %%
data = pd.read_csv("movies.csv")
#462 ID нет в списке 
data[ data.movieId == 586].head()
# Out:
#      movieId              title           genres
# 504      586  Home Alone (1990)  Children|Comedy

# %%
#Задание 2
"""
По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония)
категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.
"""

# %%
data2 = pd.read_csv("power.csv")
data2[ data2["country"].str.contains("est", case = False)]["country"].unique()
# Out:
# array(['Estonia', 'State of Palestine', 'Timor-Leste'], dtype=object)

# %%
country_x = ["Latvia", "Lithuania", "Estonia" ]
category_x = [4, 12, 21]

data2.loc[ 
    (data2["country"].isin(country_x) & 
    (data2["category"].isin(category_x)) &
    (data2["year"] > 2004)  & (data2["year"] < 2011)
    )              
         ].head(100)
# Out:
#           country  year  quantity  category
# 10617     Estonia  2008       1.0         4
# 10618     Estonia  2007       0.0         4
# 10619     Estonia  2006       0.0         4
# 10620     Estonia  2005       1.0         4
# 11156   Lithuania  2008       1.0         4
# ...           ...   ...       ...       ...
# 107658  Lithuania  2010     142.0        12
# 107659  Lithuania  2009     109.0        12
# 107660  Lithuania  2008     121.0        12
# 107661  Lithuania  2007     165.0        12
# 107662  Lithuania  2006       3.0        12
#
# [100 rows x 4 columns]

# %%
#Задание 3
"""
Выберите страницу любого сайта с табличными данными. 
Импортируйте таблицы в pandas dataframe.
"""

# %%
pd.read_html("https://fortrader.org/quotes")
# Out:
# [                           Название   Цена  Изменение  Изменение(%)  Обновлено
#  0  EURRUB Курс евро к рублю сегодня  92.07       0.89          0.98        NaN
#  1       USDRUB Курс рубля к доллару  77.44       0.84          1.09        NaN,
#                                Название    Цена  Изменение  Изменение(%)  \
#  0       Нефть Brent Курс нефти сегодня   62.88      -0.49         -0.77
#  1          Нефть WTI Цены на нефть WTI   59.30      -0.45         -0.75
#  2  Природный газ Цена на природный газ    2.54       0.02          0.91
#  3                                 Кофе  127.70      -0.35         -0.27
#  4                             Кукуруза  582.20       3.00          0.52
#  5                                  Соя  407.00       0.20          0.05
#  6                               Хлопок   83.37       1.96          2.41
#
#     Обновлено
#  0        NaN
#  1        NaN
#  2        NaN
#  3        NaN
#  4        NaN
#  5        NaN
#  6        NaN  ,
# ...
