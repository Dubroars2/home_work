# %%
#Задание 1
"""
Для датафрейма log из материалов занятия создайте столбец source_type по следующим правилам:

если источник traffic_source равен yandex или google, то в source_type ставится organic
для источников paid и email из России - ставим ad
для источников paid и email не из России - ставим other
все остальные варианты берем из traffic_source без изменений

"""

# %%
import pandas as pd

# %%
log = pd.read_csv("visit_log.csv", sep = ";")

# %%
def source_type_func(new_list):
    if new_list["traffic_source"] == "yandex":
        return "organic"
    if new_list["traffic_source"] == "google":
        return "organic"
    if new_list["traffic_source"] == "paid" and new_list["region"] == "Russia":
        return "ad"
    if new_list["traffic_source"] =="email" and new_list["region"] =="Russia":
        return "ad"
    if new_list["traffic_source"] =="email" or new_list["traffic_source"] =="paid" and new_list["region"] != "Russia":
        return "Other"
    
    return new_list["traffic_source"]

# %%
log["source_type"] = log.apply(source_type_func, axis = 1)
log.head(40)
# Out:
#      timestamp    visit_id                                 url   region  \
# 0   1549980692  e3b0c44298  https://host.ru/3c19b4ef7371864fa3   Russia
# 1   1549980704  6e340b9cff  https://host.ru/c8d9213a31839f9a3a   Russia
# 2   1549980715  96a296d224  https://host.ru/b8b58337d272ee7b15   Russia
# 3   1549980725  709e80c884  https://host.ru/b8b58337d272ee7b15   Russia
# 4   1549980736  df3f619804  https://host.ru/b8b58337d272ee7b15   Russia
# 5   1549980742  8855508aad  https://host.ru/df646c3676cc259fa0   Russia
# 6   1549980742  b0f66adc83  https://host.ru/b8b58337d272ee7b15   Russia
# 7   1549980754  837885c8f8  https://host.ru/108ce4b365afb7b88e   Russia
# 8   1549980760  af5570f5a1  https://host.ru/3004a8273caeef2867    China
# 9   1549980765  3e7077fd2f  https://host.ru/df646c3676cc259fa0   Russia
# 10  1549980777  01d448afd9  https://host.ru/a5dda93e70318570c0    India
# 11  1549980785  71b6c1d538  https://host.ru/c8d9213a31839f9a3a  Ukraine
# ...

# %%
#Задание 2
"""
В файле URLs.txt содержатся url страниц новостного сайта. 
Вам необходимо отфильтровать его по адресам страниц с текстами новостей. 
Известно, что шаблон страницы новостей имеет внутри url следующую конструкцию: /, затем 8 цифр, затем дефис. 
Выполните следующие действия:

Прочитайте содержимое файла с датафрейм
Отфильтруйте страницы с текстом новостей, используя метод str.contains и регулярное выражение в соответствии 
с заданным шаблоном

"""

# %%
df = pd.read_csv("URLs.txt")
df["adress"] = df["url"].str.contains(r'(?<=/)\d+-')
filter_true = df.loc[df.adress == True]
filter_true.head()
# Out:
#                                                  url  adress
# 3  /politics/36188461-s-marta-zhizn-rossiyan-susc...    True
# 4  /world/36007585-tramp-pridumal-kak-reshit-ukra...    True
# 5  /science/36157853-nasa-sobiraet-ekstrennuyu-pr...    True
# 6  /video/36001498-poyavilis-pervye-podrobnosti-g...    True
# 7  /world/36007585-tramp-pridumal-kak-reshit-ukra...    True

# %%
#Задание 3
"""
Используйте файл с оценками фильмов ml-latest-small/ratings.csv. 
Посчитайте среднее время жизни пользователей, которые выставили более 100 оценок. 
Под временем жизни понимается разница между максимальным и минимальным значением столбца timestamp 
для данного значения userId.
"""

# %%
import pandas as pd

# %%
# Сделаем таблицу ключ с нужными ID (более 100 оценок)
data = pd.read_csv("доп материалы/ml-latest-small/ratings.csv")
data_count = data.drop(["movieId","timestamp"],axis =1).groupby("userId").count().rename(columns={"rating":"count"})
data_count = data_count.loc[data_count["count"] > 100]
data_count.head()
# Out:
#         count
# userId
# 4         204
# 8         116
# 15       1700
# 17        363
# 19        423

# %%
# Делаем join макс время и отсавляем только те ID, где больше 100 оценок.
for_max_data = data_count.join(max_data_pivot, how = "inner").drop(["count"], axis=1)
for_max_data.head()
# Out:
#                max
# userId
# 4        949982274
# 8       1154474527
# 15      1469330735
# 17      1127476640
# 19       855195373

# %%
# Делаем join мин время и отсавляем только те ID, где больше 100 оценок.
for_min_data = data_count.join(min_data_pivot, how = "inner").drop(["count"], axis=1)
for_min_data.head()
# Out:
#                min
# userId
# 4        949778714
# 8       1154389340
# 15       997937239
# 17      1127468587
# 19       855190091

# %%
# объединим мин и макс даты в один датафрейм и находим разницу
final_data = for_min_data.join(for_max_data, how = "left")
final_data["Average_time"] = final_data["max"] - final_data["min"] 
final_data.head()
# Out:
#                min         max  Average_time
# userId
# 4        949778714   949982274        203560
# 8       1154389340  1154474527         85187
# 15       997937239  1469330735     471393496
# 17      1127468587  1127476640          8053
# 19       855190091   855195373          5282

# %%
#Находим максимлаьное время для каждого ID
max_data_pivot = data.pivot_table(
    index = "userId",
    values='timestamp',
    aggfunc = "max",
    fill_value = 0).rename(columns={"timestamp":"max"})
max_data_pivot.head(8)
# Out:
#                max
# userId
# 1       1260759205
# 2        835356246
# 3       1298932787
# 4        949982274
# 5       1163375145
# 6       1109258285
# 7        851869291
# 8       1154474527

# %%
#Находим минимальное  время для каждого ID
min_data_pivot = data.pivot_table(
    index = "userId",
    values='timestamp',
    aggfunc = "min",
    fill_value = 0).rename(columns={"timestamp":"min"})
min_data_pivot.head(8)
# Out:
#                min
# userId
# 1       1260759108
# 2        835355395
# 3       1298861589
# 4        949778714
# 5       1163373044
# 6       1108134263
# 7        851866703
# 8       1154389340

# %%
#Задание 4
"""
Дана статистика услуг перевозок клиентов компании по типам (см. файл с кодом занятия).
Необходимо сформировать две таблицы:
таблицу с тремя типами выручки для каждого client_id без указания адреса клиента
аналогичную таблицу по типам выручки с указанием адреса клиента
Обратите внимание, что в процессе объединения таблиц данные не должны теряться.

# %%
import pandas as pd
